# %% [markdown]
# ## Working-With-APIs

# %% [markdown]
# ### 1. BC Ferries API

# %%
from pandas.io.json import json_normalize
import requests

# %%
response = requests.get('https://bcferriesapi.ca/api/')
results = response.json()

# %%
response.status_code
#API Fetching is successful
# Out:
# 200

# %%
results
# Out:
# {'schedule': {'BOW': {'HSB': {'sailingDuration': '',
#     'sailings': [{'time': '5:20 am',
#       'arrivalTime': '5:40 am',
#       'isCancelled': False,
#       'fill': 0,
#       'carFill': 0,
#       'oversizeFill': 0,
#       'vesselName': '',
#       'vesselStatus': ''},
#      {'time': '6:20 am',
#       'arrivalTime': '6:40 am',
#       'isCancelled': False,
#       'fill': 0,
#       'carFill': 0,
#       'oversizeFill': 0,
#       'vesselName': '',
#       'vesselStatus': ''},
#      {'time': '7:30 am',
#       'arrivalTime': '7:50 am',
#       'isCancelled': False,
#       'fill': 0,
#       'carFill': 0,
#       'oversizeFill': 0,
#       'vesselName': '',
#       'vesselStatus': ''},
#      {'time': '8:35 am',
#       'arrivalTime': '8:55 am',
#       'isCancelled': False,
#       'fill': 0,
#       'carFill': 0,
#       'oversizeFill': 0,
#       'vesselName': '',
#       'vesselStatus': ''},
#      {'time': '9:40 am',
#       'arrivalTime': '10:00 am',
# ...

# %%
flattend_data=json_normalize(results)
flattend_data.T
# Out:
# <ipython-input-9-aa7130d1d7f0>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattend_data=json_normalize(results)
#                                                                                   0
# scrapedAt                                            2023-04-01T12:44:35.084483214Z
# schedule.BOW.HSB.sailingDuration
# schedule.BOW.HSB.sailings         [{'time': '5:20 am', 'arrivalTime': '5:40 am',...
# schedule.DUK.TSA.sailingDuration
# schedule.DUK.TSA.sailings         [{'time': '7:45 AM', 'arrivalTime': '', 'isCan...
# schedule.FUL.SWB.sailingDuration
# schedule.FUL.SWB.sailings         [{'time': '6:15 am', 'arrivalTime': '6:50 am',...
# schedule.HSB.BOW.sailingDuration
# schedule.HSB.BOW.sailings         [{'time': '5:50 AM', 'arrivalTime': '', 'isCan...
# schedule.HSB.LNG.sailingDuration
# schedule.HSB.LNG.sailings         [{'time': '7:30 AM', 'arrivalTime': '', 'isCan...
# schedule.HSB.NAN.sailingDuration
# ...

# %% [markdown]
# ### 2. Mutual funds in India

# %%
response2 = requests.get('https://api.mfapi.in/mf')
results2 = response.json()
response2.status_code
# Out:
# 200

# %%
flattend_data2=json_normalize(results2)
flattend_data2
# Out:
# <ipython-input-14-f635bfc2cbec>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattend_data2=json_normalize(results2)
#        schemeCode                                         schemeName
# 0          100027  Grindlays Super Saver Income Fund-GSSIF-Half Y...
# 1          100028  Grindlays Super Saver Income Fund-GSSIF-Quater...
# 2          100029     Grindlays Super Saver Income Fund-GSSIF-Growth
# 3          100030  Grindlays Super Saver Income Fund-GSSIF-Annual...
# 4          100031  Grindlays Super Saver Income Fund-GSSIF - ST-D...
# ...           ...                                                ...
# 45073      151702  Aditya Birla Sun Life Fixed Term Plan - Series...
# 45074      151703  Aditya Birla Sun Life Fixed Term Plan - Series...
# 45075      151708  Nippon India Fixed Horizon Fund-XLV-Series 5-D...
# 45076      151710  Nippon India Fixed Horizon Fund-XLV-Series 5-R...
# ...

# %% [markdown]
# ### 3. US Treasury Dept

# %%
response3 = requests.get('https://api.fiscaldata.treasury.gov/services/api/fiscal_service/v1/accounting/od/rates_of_exchange?fields=country_currency_desc,exchange_rate,%20record_date&filter=record_date:gte:2015-01-01')
results3 = response3.json()
response3.status_code
# Out:
# 200

# %%
flattend_data3=json_normalize(results3)
flattend_data3
# Out:
# <ipython-input-4-a6e2771ffc96>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattend_data3=json_normalize(results3)
#                                                 data  meta.count  \
# 0  [{'country_currency_desc': 'AFGHANISTAN-AFGHAN...         100
#
#   meta.labels.country_currency_desc meta.labels.exchange_rate  \
# 0    Country - Currency Description             Exchange Rate
#
#   meta.labels.record_date meta.dataTypes.country_currency_desc  \
# 0             Record Date                               STRING
#
#   meta.dataTypes.exchange_rate meta.dataTypes.record_date  \
# 0                       NUMBER                       DATE
#
#   meta.dataFormats.country_currency_desc meta.dataFormats.exchange_rate  \
# 0                                 String                           10.2
#
#   meta.dataFormats.record_date  meta.total-count  meta.total-pages  \
# 0                   YYYY-MM-DD              6194                62
# ...

# %% [markdown]
# ## 4. Wall street Journal release

# %%
url4 = 'https://newsapi.org/v2/everything?domains=wsj.com&apiKey=f0891beff53347f297c4ce12326063d1'
response4 = requests.get(url4)
results4 = response4.json()['articles']

# %%
flattened_data4 = json_normalize(results4)
flattened_data4
# Out:
# <ipython-input-9-e9e8f9daa6ef>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data4 = json_normalize(results4)
#                                   author  \
# 0                                    wsj
# 1                        Yuliya Chernova
# 2                                    wsj
# 3                                    wsj
# 4   Berber Jin, Keach Hagey, Clara Mokri
# 5                           Miles Kruppa
# 6                                    wsj
# 7                                    wsj
# 8                                    wsj
# 9                                    wsj
# 10                                   wsj
# 11                                   wsj
# 12                                   wsj
# 13                                   wsj
# 14               Jing Yang, and, Shen Lu
# 15                                   wsj
# 16                   Alexander Gladstone
# 17                            Ian Buruma
# ...
